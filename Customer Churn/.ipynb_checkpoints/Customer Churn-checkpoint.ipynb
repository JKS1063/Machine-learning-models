# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('customer_churn.csv')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.shape
# Out:
# (7043, 21)

# %% [markdown]
# #### Check info of dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# #### Check dataset for null values

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# #### Stripping of white spaces in "String" datatype and replacing empty rows with null values

# %%
for i in data.columns:
    if data[i].dtype == 'object':
        data[i] = data[i].str.strip(' ')
        data[i] = data[i].replace('', None)

# %% [markdown]
# #### Check again for null values

# %%
data.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# #### Getting null rows

# %%
null_rows = data[data.isnull().any(axis = 1)]

# %%
null_rows
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# #### Deleting null rows as there are only a few them present

# %%
data.dropna(inplace = True)

# %%
data.shape
# Out:
# (7032, 21)

# %% [markdown]
# #### Check and change the column data type if it is wrong

# %%
data.TotalCharges = data.TotalCharges.astype('float').round(2)

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# #### Check for outliers

# %%
sns.boxplot(data.tenure).set_title('Tenure')
plt.show()

# %%
sns.boxplot(data.MonthlyCharges).set_title('Monthly Charges')
plt.show()

# %%
sns.boxplot(data.TotalCharges).set_title('Total Charges')
plt.show()

# %% [markdown]
# ### 1. Data Manipulation

# %%
customer_5 = data.iloc[4]

# %%
customer_5
# Out:
# customerID                9237-HQITU
# gender                        Female
# SeniorCitizen                      0
# Partner                           No
# Dependents                        No
# tenure                             2
# PhoneService                     Yes
# MultipleLines                     No
# InternetService          Fiber optic
# OnlineSecurity                    No
# OnlineBackup                      No
# DeviceProtection                  No
# TechSupport                       No
# StreamingTV                       No
# StreamingMovies                   No
# Contract              Month-to-month
# PaperlessBilling                 Yes
# PaymentMethod       Electronic check
# MonthlyCharges                  70.7
# TotalCharges                  151.65
# Churn                            Yes
# Name: 4, dtype: object

# %%
customer_15 = data.iloc[14]

# %%
customer_15
# Out:
# customerID                5129-JLPIS
# gender                          Male
# SeniorCitizen                      0
# Partner                           No
# Dependents                        No
# tenure                            25
# PhoneService                     Yes
# MultipleLines                     No
# InternetService          Fiber optic
# OnlineSecurity                   Yes
# OnlineBackup                      No
# DeviceProtection                 Yes
# TechSupport                      Yes
# StreamingTV                      Yes
# StreamingMovies                  Yes
# Contract              Month-to-month
# PaperlessBilling                 Yes
# PaymentMethod       Electronic check
# MonthlyCharges                 105.5
# TotalCharges                 2686.05
# Churn                             No
# Name: 14, dtype: object

# %%
senior_male_electonic = data[(data.gender == 'Male') & (data.SeniorCitizen == 1) & (data.PaymentMethod == 'Electronic check')]

# %%
senior_male_electonic
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV   Male              1      No         No       1
# 55    1658-BYGOY   Male              1      No         No      18
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# 78    0191-ZHSKZ   Male              1      No         No      30
# 91    2424-WVHPL   Male              1      No         No       1
# ...          ...    ...            ...     ...        ...     ...
# 6837  6229-LSCKB   Male              1      No         No       6
# 6894  1400-MMYXY   Male              1     Yes         No       3
# 6914  7142-HVGBG   Male              1     Yes         No      43
# 6967  8739-WWKDU   Male              1      No         No      25
# 7032  6894-LFHLY   Male              1      No         No       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %%
customer_total_tenure = data[(data.tenure > 70) | (data.MonthlyCharges > 100)]

# %%
customer_total_tenure
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 8             Yes           Yes     Fiber optic                   No  ...
# ...

# %%
data.Contract.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
data.PaymentMethod.unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
data.Churn.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
two_mail_yes = data[(data.Contract == 'Two year') & (data.PaymentMethod == 'Mailed check') & (data.Churn == 'Yes')]

# %%
two_mail_yes
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %%
customer_333 = data.sample(n = 333) #picking random rows

# %%
customer_333
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3976  5261-QSHQM  Female              0      No         No       4
# 1722  9060-HJJRW  Female              0      No         No      51
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 1741  0106-GHRQR    Male              0      No         No      16
# 3122  8395-ETZKQ    Male              1     Yes        Yes      68
# ...          ...     ...            ...     ...        ...     ...
# 869   0323-XWWTN    Male              0      No        Yes       3
# 837   6982-SSHFK    Male              0      No         No       1
# 433   2957-LOLHO    Male              0      No         No      12
# 5670  7812-FZHPE  Female              0     Yes        Yes      17
# 3487  9257-AZMTZ  Female              0     Yes        Yes      52
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 3976           No  No phone service             DSL                   No  ...
# ...

# %%
Churn = data.Churn.value_counts()

# %%
Churn
# Out:
# Churn
# No     5163
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# ### 2. Data Visualzation

# %%
internet = data.InternetService.value_counts().keys()
counts = data.InternetService.value_counts()
sns.barplot(x = internet, y =  counts, color = 'orange')
for index, value in enumerate(list(counts)):
    plt.text(index, value,
            str(value), fontweight = 'bold')
plt.xlabel('Categories of Internet Service', fontweight = 'bold')
plt.ylabel('Count of Categories', fontweight = 'bold')
plt.title('Distribution of Internet Service', fontweight = 'bold')
plt.show()

# %%
sns.histplot(data.tenure, bins = 30, color = 'green')
plt.title('Distribution of tenure', fontweight = 'bold')
plt.xlabel('Tenure', fontweight = 'bold')
plt.ylabel('Customer count', fontweight = 'bold')
plt.grid()
plt.show()

# %% [markdown]
# * From the above graph it can be interpreted that most of the customers are new
# * Most of the customers are staying with company
# * There are very less number of customers around 45 month Tenure time

# %%
plt.figure(figsize = (10, 6))
sns.scatterplot(x = data.tenure, y = data.MonthlyCharges, color = 'brown')
plt.xlabel('Tenure of customer', fontweight = 'bold')
plt.ylabel('Monthly Charges of customer', fontweight = 'bold')
plt.title('Tenure vs Monthly Charges', fontweight = 'bold')
plt.show()

# %% [markdown]
# * Montly Charges are increasing with each tenure.
# * Customers who are having least amount of time are paying less charges compared to customers with most tenure time.

# %%
plt.figure(figsize = (8,6))
sns.boxplot(x = data.Contract, y = data.tenure)
plt.xlabel('Contract', fontweight = 'bold')
plt.ylabel('Tenure', fontweight = 'bold')
plt.title('Tenure & Contract', fontweight = 'bold')
plt.grid(True)
plt.show()

# %% [markdown]
# * Two year contract custmers are having highest tenure with company followed by One-year and month-to-month.
# * Two year contract: customers who opted for this contract have the least tenure time of 15 months and most being as around 75 months with the company. Customers who are opting this contract have an average of 63 months as tenure time with company.
# * One year contract: customers who opted for this contract have the least tenure time of one month and most being as around 75 months with the company. Customers who are opting this contract have an average of 44 months as tenure time with company.
# * Month-to-Month contract: customers who opted for this contract have the least tenure time of 1 month and most being as around 68 months with the company. Customers who are opting this contract have an average of 12 months as tenure time with company.
# * We can say that most of the old customers having hith tenure time are preferring Two year contract, followed by One year contract.
# * Most of the new customers having least tenure time with company are opting for month-to-month contract.

# %% [markdown]
# #### Feature selection

# %%
df = data.copy()

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.drop(columns = ['customerID'], inplace = True)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtype == 'object':
        df[i] = le.fit_transform(df[i])

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
plt.figure(figsize = (20, 8))
sns.heatmap(df.corr(), annot = True, cmap = 'coolwarm')
plt.show()

# %%
df.gender.unique()
# Out:
# array([0, 1])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

col_list = []

for i in df.columns:
    if i != 'Churn':
        col_list.append(i)

# %%
x = df[col_list]
vif_data = pd.DataFrame()
vif_data['features'] = x.columns
vif_data['VIF'] = [variance_inflation_factor(x.values, i)
                  for i in range(len(x.columns))]

# %%
print(vif_data)
# Out:
#             features        VIF
# 0             gender   1.954535
# 1      SeniorCitizen   1.369954
# 2            Partner   2.819229
# 3         Dependents   1.957360
# 4             tenure  15.084412
# 5       PhoneService  15.150758
# 6      MultipleLines   2.756988
# 7    InternetService   4.350001
# 8     OnlineSecurity   2.247863
# 9       OnlineBackup   2.455913
# 10  DeviceProtection   2.629892
# 11       TechSupport   2.381046
# 12       StreamingTV   3.237958
# 13   StreamingMovies   3.265595
# 14          Contract   4.194484
# 15  PaperlessBilling   2.875010
# 16     PaymentMethod   3.095143
# 17    MonthlyCharges  20.503844
# 18      TotalCharges  13.869098

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
df.shape
# Out:
# (7032, 20)

# %% [markdown]
# ### 3. Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
HeatmapLabels = ['True', 'False']

# %% [markdown]
# #### Linear Regression Model

# %%
x1 = df[['tenure']]
y1 = df.MonthlyCharges

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1,
                                                        test_size = 0.3,
                                                        random_state = 42)

# %%
lir = LinearRegression()

# %%
lir.fit(x1_train, y1_train)
# Out:
# LinearRegression()

# %%
lir_predict = lir.predict(x1_test)

# %%
print('R-sq value:', round(metrics.r2_score(y1_test, lir_predict), 2))
# Out:
# R-sq value: 0.07

# %%
error = round(np.sqrt(metrics.mean_squared_error(y1_test, lir_predict)), 2)
error
# Out:
# 28.97

# %%
sns.distplot(y1_test, label = 'Actual')
sns.distplot(lir_predict, label = 'Predicted')
plt.legend()
plt.show()

# %% [markdown]
# #### Logistic Regression Model

# %%
x2 = df[['MonthlyCharges']]
y2 = df.Churn

# %%
x2_train, x2_test, y2_train, y2_test = train_test_split(x2, y2, 
                                                        test_size = 0.35,
                                                        random_state = 42,
                                                        shuffle = True)

# %%
lor = LogisticRegression()

# %%
lor.fit(x2_train, y2_train)
# Out:
# LogisticRegression()

# %%
lor_predict = lor.predict(x2_test)

# %%
print('Logistic Regression Accuracy Score:',round(metrics.accuracy_score(y2_test, lor_predict), 2))
# Out:
# Logistic Regression Accuracy Score: 0.74

# %%
cm = metrics.confusion_matrix(y2_test, lor_predict)

sns.heatmap(cm, annot = True, vmin = 0, vmax = 400, fmt = '.2f',
            xticklabels=HeatmapLabels, yticklabels=HeatmapLabels)
# Out:
# <Axes: >

# %%
sns.distplot(y2_test, label = 'Actual')
sns.distplot(lor_predict, label = 'Predicted')
plt.legend()
plt.show()

# %%
print(metrics.classification_report(y2_test, lor_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85      1824
#            1       0.00      0.00      0.00       638
#
#     accuracy                           0.74      2462
#    macro avg       0.37      0.50      0.43      2462
# weighted avg       0.55      0.74      0.63      2462

# %%
x2_1 = df[['MonthlyCharges', 'tenure']]
y2_1 = df.Churn

# %%
x2_1_train, x2_1_test, y2_1_train, y2_1_test = train_test_split(x2_1, y2_1,
                                                                test_size = 0.2,
                                                                random_state = 42,
                                                                shuffle = True)

# %%
lor.fit(x2_1_train, y2_1_train)
# Out:
# LogisticRegression()

# %%
lor_predict_2 = lor.predict(x2_1_test)

# %%
print('Logistic Regression Accuracy Score:', round(metrics.accuracy_score(y2_1_test, lor_predict_2), 2))
# Out:
# Logistic Regression Accuracy Score: 0.78

# %%
cm2 = metrics.confusion_matrix(y2_1_test, lor_predict_2)

sns.heatmap(cm2, annot = True, vmin = 0, vmax = 400, fmt = '.2f',
            xticklabels=HeatmapLabels, yticklabels=HeatmapLabels)
# Out:
# <Axes: >

# %%
sns.distplot(y2_1_test, label = 'Actual')
sns.distplot(lor_predict_2, label = 'Predicted')
plt.legend()
plt.show()

# %%
print(metrics.classification_report(y2_1_test, lor_predict_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.91      0.86      1033
#            1       0.63      0.43      0.51       374
#
#     accuracy                           0.78      1407
#    macro avg       0.72      0.67      0.68      1407
# weighted avg       0.76      0.78      0.76      1407

# %% [markdown]
# #### Decision Tree Classification model

# %%
x3 = df[['tenure']]
y3 = df.Churn

# %%
x3_train, x3_test, y3_train, y3_test = train_test_split(x3, y3,
                                                        test_size = 0.2,
                                                        random_state = 42,
                                                        shuffle = True)

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x3_train, y3_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc_predict = dtc.predict(x3_test)

# %%
print('Decision Tree Model Accuracy Score:', round(metrics.accuracy_score(y3_test, dtc_predict), 2))
# Out:
# Decision Tree Model Accuracy Score: 0.75

# %%
cm3 = metrics.confusion_matrix(y3_test, dtc_predict)

sns.heatmap(cm3, annot = True, vmin = 0, vmax = 400, fmt = '0.2f',
            xticklabels=HeatmapLabels, yticklabels=HeatmapLabels)
# Out:
# <Axes: >

# %%
sns.distplot(y3_test, label = 'Actual')
sns.distplot(dtc_predict, label = 'Predicted')
plt.legend()
plt.show()

# %%
print(metrics.classification_report(y3_test, dtc_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.91      0.84      1033
#            1       0.56      0.32      0.40       374
#
#     accuracy                           0.75      1407
#    macro avg       0.67      0.61      0.62      1407
# weighted avg       0.73      0.75      0.73      1407

# %% [markdown]
# #### Random Forest Model

# %%
x4 = df[['tenure', 'MonthlyCharges']]
y4 = df.Churn

# %%
x4_train, x4_test, y4_train, y4_test = train_test_split(x4, y4, 
                                                        test_size = 0.3,
                                                        random_state = 42,
                                                        shuffle = True)

# %%
rfc = RandomForestClassifier(n_estimators = 500)

# %%
rfc.fit(x4_train, y4_train)
# Out:
# RandomForestClassifier(n_estimators=500)

# %%
rfc_predict = rfc.predict(x4_test)

# %%
print('Random Forest Model Accuracy score:', round(metrics.accuracy_score(y4_test, rfc_predict), 2))
# Out:
# Random Forest Model Accuracy score: 0.74

# %%
cm4 = metrics.confusion_matrix(y4_test, rfc_predict)

sns.heatmap(cm4, annot = True, vmin = 0, vmax = 400, fmt = '0.2f',
            xticklabels=HeatmapLabels, yticklabels=HeatmapLabels)
# Out:
# <Axes: >

# %%
sns.distplot(y4_test, label = 'Actual')
sns.distplot(rfc_predict, label = 'Predicted')
plt.legend()
plt.show()

# %%
print(metrics.classification_report(y4_test, rfc_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.82      1549
#            1       0.51      0.43      0.47       561
#
#     accuracy                           0.74      2110
#    macro avg       0.66      0.64      0.65      2110
# weighted avg       0.73      0.74      0.73      2110

# %% [markdown]
# * Logistic Regression model is having accuracy score comapred to othe models.
# * Logistic Regression model is predcting correct values followed by Decision Tree Classifier and Random Forest Classifier.

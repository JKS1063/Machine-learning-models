# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
from skimage.io import imread
from skimage.transform import resize
from PIL import Image
import numpy as np

# %%
inp_dir = 'D:/JKS/Education/వ్యక్తిగతం/Online courses/Intellipaat/Projects/Python & ML/Project Programming/Image classification/train'

# %% [markdown]
# #### Displaying the image

# %%
categories = ['cats', 'dogs']

for category in categories:
    for file in os.listdir(os.path.join(inp_dir, category)):
        img_path = os.path.join(inp_dir, category, file)
        print(img_path)
# Out:
# D:/JKS/Education/వ్యక్తిగతం/Online courses/Intellipaat/Projects/Python & ML/Project Programming/Image classification/train\cats\cat.0.jpg
# D:/JKS/Education/వ్యక్తిగతం/Online courses/Intellipaat/Projects/Python & ML/Project Programming/Image classification/train\cats\cat.1.jpg
# D:/JKS/Education/వ్యక్తిగతం/Online courses/Intellipaat/Projects/Python & ML/Project Programming/Image classification/train\cats\cat.10.jpg
# D:/JKS/Education/వ్యక్తిగతం/Online courses/Intellipaat/Projects/Python & ML/Project Programming/Image classification/train\cats\cat.100.jpg
# D:/JKS/Education/వ్యక్తిగతం/Online courses/Intellipaat/Projects/Python & ML/Project Programming/Image classification/train\cats\cat.101.jpg
# D:/JKS/Education/వ్యక్తిగతం/Online courses/Intellipaat/Projects/Python & ML/Project Programming/Image classification/train\cats\cat.102.jpg
# D:/JKS/Education/వ్యక్తిగతం/Online courses/Intellipaat/Projects/Python & ML/Project Programming/Image classification/train\cats\cat.103.jpg
# ...

# %%
Image.open('D:/JKS/Education/వ్యక్తిగతం/Online courses/Intellipaat/Projects/Python & ML/Project Programming/Image classification/train\cats\cat.113.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=409x308>

# %% [markdown]
# #### Converting image to numpy array

# %%
img_path
# Out:
# 'D:/JKS/Education/వ్యక్తిగతం/Online courses/Intellipaat/Projects/Python & ML/Project Programming/Image classification/train\\dogs\\dog.999.jpg'

# %%
img = imread(img_path)

# %%
print(img)
# Out:
# [[[137 161 187]
#   [130 152 176]
#   [131 149 169]
#   ...
#   [223 235 213]
#   [223 235 213]
#   [223 235 213]]
#
#  [[125 147 171]
#   [119 139 163]
#   [123 140 158]
#   ...
#   [221 233 209]
#   [220 232 208]
#   [220 232 208]]
#
#  [[113 131 155]
#   [111 128 148]
#   [116 132 148]
#   ...
#   [223 236 208]
#   [223 236 208]
#   [223 236 208]]
#
#  ...
#
#  [[153 148 152]
#   [164 158 162]
#   [164 153 159]
#   ...
#   [223 182 188]
#   [223 182 188]
#   [223 182 188]]
#
#  [[153 148 152]
#   [163 157 161]
#   [164 153 159]
#   ...
#   [225 184 190]
#   [225 184 190]
#   [225 184 190]]
#
#  [[153 148 152]
#   [163 157 161]
#   [163 152 158]
#   ...
#   [226 185 191]
#   [226 185 191]
#   [226 185 191]]]

# %% [markdown]
# #### Resizing and flattening the array

# %%
img = resize(img, (15, 15))
img = img.flatten()
print(img)
# Out:
# [0.57150566 0.5697045  0.59762949 0.69355922 0.70425635 0.6760147
#  0.7274073  0.74316296 0.68453454 0.63550838 0.64226682 0.59413882
#  0.52762733 0.51846931 0.49848052 0.48419254 0.46225855 0.47412898
#  0.45714232 0.43267924 0.45143806 0.52317352 0.50311748 0.5221659
#  0.59727609 0.58744775 0.57809449 0.69178214 0.69730264 0.65978792
#  0.76750452 0.78340953 0.72499845 0.77233852 0.78728788 0.72744289
#  0.77598811 0.79214907 0.73300889 0.77919238 0.79202494 0.7359423
#  0.77063584 0.78518105 0.72901601 0.61378367 0.58526163 0.58826827
#  0.59273656 0.58828983 0.59152255 0.54363933 0.53342772 0.51264778
#  0.4398219  0.41373543 0.43899198 0.47503982 0.43168968 0.49938868
#  0.54328145 0.47494809 0.5444035  0.4498075  0.40892697 0.4789003
#  0.42640553 0.39564564 0.46098995 0.39239651 0.36535804 0.40887841
#  0.40707523 0.39982981 0.40055979 0.62001896 0.62539701 0.58702095
#  0.74337249 0.75564253 0.69981747 0.76135833 0.77299647 0.71735103
# ...

# %% [markdown]
# #### Convert and flatten all images and store in variables

# %%
data = []
labels  = []

for category_idx, category in enumerate(categories):
    for file in os.listdir(os.path.join(inp_dir, category)):
        img_path = os.path.join(inp_dir, category, file)
        img = imread(img_path)
        img = resize(img, (100 ,100))
        data.append(img.flatten())
        labels.append(category_idx)

# %%
data = np.asarray(data)
labels = np.asarray(labels)

# %% [markdown]
# #### Split data into Train and Test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data, labels,
                                                   test_size = 0.2,
                                                   shuffle = True,
                                                   stratify = labels)

# %% [markdown]
# #### Standardizing the data

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %% [markdown]
# #### Logistic Regression

# %%
# from sklearn.linear_model import LogisticRegression

# lr = LogisticRegression()
# lr.fit(x_train, y_train)

# y_pred = lr.predict(x_test)

# from sklearn.metrics import accuracy_score

# accuracy_score(y_pred, y_test)

# %% [markdown]
# #### Decision Tree

# %%
# from sklearn.tree import DecisionTreeClassifier

# from sklearn.metrics import accuracy_score

# dt = DecisionTreeClassifier()

# dt.fit(x_train, y_train)

# y_pred = dt.predict(x_test)

# accuracy_score(y_test, y_pred)

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score

# %%
rfc = RandomForestClassifier(n_estimators = 1000)

rfc.fit(x_train, y_train)

y_pred = rfc.predict(x_test)

print(f"Accuracy for Random Forest data is : {accuracy_score(y_pred, y_test)}")
# Out:
# Accuracy for Random Forest data is : 0.6625

# %% [markdown]
# #### Hyperparameter Tuning - Random Forest

# %%
# rfc = RandomForestClassifier(random_state = 42)

# para_grid = {
#     'n_estimators' : [200, 1000],
#     'max_features' : ['auto', 'sqrt', 'log2'],
#     'max_depth' : [4, 5, 6, 7, 8],
#     'criterion' : ['gini', 'entropy']
# }

# from sklearn.model_selection import GridSearchCV

# CV_rfc = GridSearchCV(estimator = rfc, param_grid = para_grid, cv = 5)

# CV_rfc.fit(x_train, y_train)
# CV_rfc.best_params_

# rfc1 = RandomForestClassifier(random_state = 42, max_features = 'log2', 
#                               max_depth = 7, n_estimators = 200, 
#                              criterion = 'gini')

# rfc1.fit(x_train, y_train)

# y_pred = rfc1.predict(x_test)

# print(f"Accuracy for Random Forest on data: {accuracy_score(y_test, y_pred)}")

# %%
import pandas as pd
Act_Pred = pd.DataFrame({'Actual' : y_test, 'Predicted' : y_pred})

Act_Pred
# Out:
#      Actual  Predicted
# 0         0          0
# 1         0          0
# 2         0          0
# 3         1          0
# 4         1          1
# ..      ...        ...
# 395       1          0
# 396       1          0
# 397       1          1
# 398       1          1
# 399       1          0
#
# [400 rows x 2 columns]

# %%
x_test[0].shape
# Out:
# (30000,)

# %%
rfc.predict([x_test[0]])
# Out:
# array([0])

# %%
for x in range(11):
    if rfc.predict([x_test[x]]) == 0:
        print('Cat')
    elif rfc.predict([x_test[x]]) == 1:
        print('Dog')
# Out:
# Cat
# Cat
# Cat
# Cat
# Dog
# Dog
# Cat
# Dog
# Cat
# Cat
# Cat

# %%
img.shape
# Out:
# (100, 100, 3)

# %%
a = x_test[0].reshape(100,100,3)

# %%
a = a.astype('uint8')

# %%
type(a)
# Out:
# numpy.ndarray

# %%
image = Image.fromarray(a, mode = 'RGB')

# %%
image.show()

# %%
image.save('my.png')
